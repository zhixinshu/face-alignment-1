# %%
import face_alignment
import skimage.io as io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import torch

# %%
fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._2D, enable_cuda=True, flip_input=False)
# Out:
# Using CNN face detector
# /home/zhshu/.face_alignment/data/mmod_human_face_detector.dat
# 4
# /home/zhshu/.face_alignment/data

# %%
input = io.imread('/nfs/bigdisk/zhshu/data/fare/real/multipie_select_batches/session01_select_test/light_00_012_01/012_01_01_010_00.png')
preds, crop = fa.get_landmarks(input)
npimg = crop[0].cpu().numpy()
npcrop = np.transpose(npimg, (1,2,0))
plt.imshow(input)
plt.show()

# %%
def DrawPointsOnImage(img,points):
    imgplot = plt.imshow(img)
    for i in range(68):
        plt.scatter(preds[0][i][0], preds[0][i][1], c='y', s=10)
    plt.show()

# %%
DrawPointsOnImage(input,preds)
