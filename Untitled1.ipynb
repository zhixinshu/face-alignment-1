# %%
from __future__ import print_function
import os
import sys
import time
import torch
import math
import numpy as np
from torch.autograd import Variable
from enum import Enum
import FANet
import skimage.io as io
import matplotlib.pyplot as plt


img2 = io.imread('/nfs/bigdisk/zhshu/Github/face-alignment/test/assets/aflw-test.jpg')
imgplot = plt.imshow(img2)
plt.show()
